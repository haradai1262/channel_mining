# %% [markdown]
# # Youtube Api V3 usage for channel mining
#
# # Install
# ### pip install --upgrade google-api-python-client
# ### pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2
# ### pip install --upgrade oauth2client

# %%
import os, sys
import pandas as pd
import datetime
from pprint import pprint
from tqdm import tqdm

import requests
from bs4 import BeautifulSoup

from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

import devkey
DEVELOPER_KEY = devkey.api1
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# 参考: https://developers.google.com/youtube/v3/docs/videos?hl=ja#resource
info_tree = {
    'id': None,
    'snippet': ['title','description','liveBroadcastContent','tags','publishedAt','thumbnails'],
    'statistics': ['viewCount','likeCount','favoriteCount','dislikeCount','commentCount'],
    'contentDetails':['caption','definition','dimension','duration','projection'],
    'topicDetails':['TopicIds', 'relevantTopicIds'],
}

channel_info_tree = {
    'id': None,
    'snippet': ['title','description','publishedAt','thumbnails'],
    'statistics': ['viewCount','subscriberCount','hiddenSubscriberCount','videoCount','commentCount'],
}

# %%
def get_channel_vlist( yt, cid, max_num ):
    channel_videos_tmp = []
    feed = yt.search().list( channelId=cid, maxResults=1, order='date', type='video', part='id' ).execute()
    nextPageToken = feed[ 'nextPageToken' ]
    video_idx = 1
    pbar = tqdm(total=max_num)
    while 1:
        if video_idx > max_num:
            break
        video_idx += 1
        pbar.update(1)
        if not 'nextPageToken' in feed: break 
        nextPageToken = feed[ 'nextPageToken' ]
        vid = feed.get('items')[0]['id']['videoId']
        channel_videos_tmp.append( vid )
        feed = yt.search().list( channelId=cid, maxResults=1, order='date', type='video', part='id', pageToken = nextPageToken ).execute()
    pbar.close()
    return channel_videos_tmp

def get_channel_vlist_quick( yt, cid, max_num ):
    channel_videos_tmp = []
    nextPageToken = ''
    page_num = 50
    # pbar = tqdm(total=max_num)
    while 1:
        feed = yt.search().list( channelId=cid, maxResults=page_num,
                                order='date', type='video', part='id', pageToken = nextPageToken
                               ).execute()
        if 'nextPageToken' in feed: nextPageToken = feed[ 'nextPageToken' ]
        else: break
        vids = [ i['id']['videoId'] for i in feed.get('items') ]
        channel_videos_tmp.extend( vids )
        # pbar.update( len(vids) )
        if len( channel_videos_tmp ) > ( max_num - 60 ): page_num = 1
        if len( channel_videos_tmp ) > max_num: break
    # pbar.close()
    return channel_videos_tmp

def get_video_detail( vid ):
    video_detail = YT.videos().list(part="id,snippet,statistics,contentDetails,topicDetails",id=vid).execute()
    return video_detail.get("items",[])[0]

def get_cols( tmp ):
    df_cols_tmp = []
    for parent, child in tmp.items():
        if child == None: df_cols_tmp.append( parent )
        else:
            for c in child: df_cols_tmp.append( c )
    return df_cols_tmp

def get_rows( channel_video_info_tmp, info_tree_tmp ):
    rows = []
    for i, v in channel_video_info_tmp.items():
        # 特定のkeyに値がない場合Noneを入れる
        for parent, child in info_tree_tmp.items():
            if not parent in v:
                v[parent] = {}
                for c in child:
                    v[parent][c] = None
            else:
                if child == None: continue
                for c in child:
                    if not c in v[parent]:
                        v[parent][c] = None
        # 
        row = []
        for parent, child in info_tree_tmp.items():
            if child == None: row.append( v[parent] )
            elif parent == 'snippet':
                for c in child:
                    if c == 'thumbnails':
                        row.append( v[parent][c]['default']['url'] )
                    else:
                        row.append( v[parent][c] )
            else:
                for c in child:
                    row.append( v[parent][c] )
        rows.append( row )
    return rows

def get_rows_channel( channel_info_tmp, channel_info_tree_tmp ):
    rows = []
    for i, channel in channel_info_tmp.items():
        # 特定のkeyに値がない場合Noneを入れる
        for parent, child in channel_info_tree_tmp.items():
            if not parent in channel:
                channel[parent] = {}
                for c in child:
                    channel[parent][c] = None
            else:
                if child == None: continue
                for c in child:
                    if not c in channel[parent]:
                        channel[parent][c] = None

        row = []
        for parent, child in channel_info_tree_tmp.items():
            if child == None: row.append( channel[parent] )
            elif parent == 'snippet':
                for c in child:
                    if c == 'thumbnails':
                        row.append( channel[parent][c]['default']['url'] )
                    else:
                        row.append( channel[parent][c] )
            else:
                for c in child:
                    row.append( channel[parent][c] )
        rows.append( row )
    return rows

# %%
# UUUM公式サイトから所属YouTuberのリストを取得
target_url = 'https://www.uuum.jp/creator/'
r = requests.get(target_url)
soup = BeautifulSoup(r.text, 'lxml')
channel_dic = {}
for i in soup.select('a[href^="https://www.youtube.com/"]'):
    url = i.get('href')
    if url[-1] == '/': url = url[:-1]
    url = url.split('/')
    channel_dic[url[4]] = url[3]

# %%
channel_dic
# Out:
# {'0214mex': 'user',
#  '70cleam': 'user',
#  'ABTVnetwork': 'user',
#  'ASFFFFD1': 'user',
#  'AmiBeautyTV': 'user',
#  'Blackbear1207': 'user',
#  'FroggyChiu': 'user',
#  'HiROKiMovies': 'user',
#  'HikakinTV': 'user',
#  'IORIKUNTV': 'user',
#  'KanonRintarou': 'c',
#  'LEON1CHANNEL1': 'user',
#  'MASAIandHamzael': 'user',
#  'MEGUMIbernadette': 'user',
#  'Maguro29Jp': 'c',
#  'MasuoTV': 'user',
#  'MizukittyV': 'user',
#  'PDSKabushikiGaisha': 'user',
#  'SRGAME1000': 'user',
#  'SeikinTV': 'user',
#  'SekineRisa': 'user',
#  'ShihoRimi': 'user',
#  'TAKASHIsTV': 'user',
#  'TUTTITV1': 'user',
#  'TheMorusaism': 'user',
#  'TokaiOnAir': 'user',
#  'UC-8H678xX1SNBOM10_ReY6Q': 'channel',
#  'UC-C5UUZqky2qJmG4EzRnI0g': 'channel',
#  'UC0JR9ZTJIvB9VX8xz7LyujA': 'channel',
#  'UC0_nOHqfcBd8Jzx9YGXJ6AQ': 'channel',
#  'UC0cpUGlqr4YlEmRG7543dEg': 'channel',
#  'UC1MwWJ2mFWp51xy9yzyhTlg': 'channel',
#  'UC2RdeFmVA1PrDqmFqJMG7hA': 'channel',
#  'UC3-I23qIQk-2rwi7cnntIJA': 'channel',
#  'UC3LAEwEhZ0Yn3l4-WatZo2Q': 'channel',
#  'UC4-TMrb7Mm4KnYx1VsUgcJA': 'channel',
#  'UC4bSJdI2RTNSld1_M_liO0w': 'channel',
#  'UC5AV3B5lr9j7TF96AESgoVQ': 'channel',
#  'UC5cDspT0XR1E3GpwVyOnwAA': 'channel',
#  'UC5l9qmpr3ym8BpyKCHio5kQ': 'channel',
#  'UC69xoWl5-Y3m-oRFTORIbKw': 'channel',
#  'UC7lG26U81JGl0EyMNOmRsjw': 'channel',
#  'UC99AIUi4psZ98Khq_qU5Hpw': 'channel',
#  'UC9YOQFPfEUXbulKDtxeqqBA': 'channel',
#  'UC9nM3v1ZWwALi0vsVuS_v5g': 'channel',
#  'UCAsviiS5DE0pcuvxPRrrAzQ': 'channel',
#  'UCCBq7s8VOCyek275uvq5lYQ': 'channel',
#  'UCCJel9mmTsxDU9RiCwdiLiA': 'channel',
#  'UCCO_itOx-wopeBohj5oPkzg': 'channel',
#  'UCD-ygDdEbVWgjIH6V1UQlbQ': 'channel',
#  'UCD3Bl7pISGIQBDMGGP2qLQw': 'channel',
#  'UCE3JA4z-hyR3VRrsRSt3udA': 'channel',
#  'UCEnkd5D-53MDGpgpiQRbUqw': 'channel',
#  'UCFKSFhVMtIu7akVuxPtXtQw': 'channel',
#  'UCHAL5c5PrCSA4ExAlY_gLuQ': 'channel',
#  'UCHV8lZJsXdW8lOFr2z8WPcg': 'channel',
#  'UCIQzfXsmjUObTWvg93gySgw': 'channel',
#  'UCJES7pjHlSyxjEOdb1PNTrA': 'channel',
#  'UCL-a2oIp9rekDc3Z79uTUPg': 'channel',
#  'UCLO1yCo0gDgpXhyM0fXfXXA': 'channel',
#  'UCLh9M5KxWSlIqh2EC8ja_ug': 'channel',
#  'UCM3yhFc0-fBFuvqx1Vg2YNQ': 'channel',
#  'UCM5R7AjTi7irA9fXorxRTRg': 'channel',
#  'UCM_Ll26nXOkscq0YSpBmgyg': 'channel',
#  'UCMsuwHzQPFMDtHaoR7_HDxg': 'channel',
#  'UCNS93jTKjnzNG7pYUCN5PrQ': 'channel',
#  'UCNaGf1tJsooAo6W_lrI06zw': 'channel',
#  'UCOZ7Kq5_VWBC-TtteAcsRBg': 'channel',
#  'UCPJOCEIyI3gxXbTqKSsViqg': 'channel',
#  'UCPyNsNSTUtywkekbDdCA_8Q': 'channel',
#  'UCPzqjzrvmSA9dVydRdAX6Xg': 'channel',
#  'UCR1_4Tla5MlZlDK8WM5vklA': 'channel',
#  'UCSdiXqnTXy6hukTURUIZbIg': 'channel',
#  'UCSrnV0SB1W2mYW4YMc9VTmg': 'channel',
#  'UCUy-lBPiJYWXTvfYHiCb_-A': 'channel',
#  'UCV_S2S-Zs8LeuJxK-T3RQQg': 'channel',
#  'UCXqocGp-RQ_sTw8EpPDg10A': 'channel',
#  'UCZ5yaAP0B-tBKl63ABFmqVQ': 'channel',
#  'UCa7KELKe1u9mQ5jWMdIB-HQ': 'channel',
#  'UCbZFgAVRN3PDZV0O6Ma-c6Q': 'channel',
#  'UCdb7Jw5rprurSCutjT9BW5A': 'channel',
#  'UCdtFmWwPlKiCOEND_95fwiA': 'channel',
#  'UCftut9Z6S48igRNSQRDpCCg': 'channel',
#  'UCg9mwxF0uacG3Q4N91wo2TQ': 'channel',
#  'UCg_Wchs_AGoHrlayD_rhO0Q': 'channel',
#  'UCgpmBtbVmsfwqhU_pU5CA3g': 'channel',
#  'UCgpq8b6bCzkSLquNQeSE6QQ': 'channel',
#  'UCh1K2JtxIZLnUaTPlxPPzjw': 'channel',
#  'UCh7bThzNArch6TgoHB1HVhA': 'channel',
#  'UCiJvvLq45i4sC4-dTiV88SQ': 'channel',
#  'UCiotlpambU2VW-eM-B2MTcg': 'channel',
#  'UCjX7kJYLEAdsaCDnTsWK3Wg': 'channel',
#  'UCj_z-Zeqk8LfwVxx0MUdL-Q': 'channel',
#  'UClX3YSREJp3ELuv2wFAYOzA': 'channel',
#  'UCmE4PWzOmGXz4eoYD_6jZ0g': 'channel',
#  'UCmol_xpWkIbQU0ZCuinqpQA': 'channel',
#  'UCmsA3A5_HKBwI9OktSttTFg': 'channel',
#  'UCoG2iDwh5Vw61kZx0kWL0WA': 'channel',
#  'UCosy7jwSdXUbLbJBYgyRcnw': 'channel',
#  'UCpOjLndjOqMoffA-fr8cbKA': 'channel',
#  'UCps4dAbzd30T--mvrCpltgw': 'channel',
#  'UCqQ6BtItfK2FI3f4wubJmoA': 'channel',
#  'UCrUfBW0jCq2HNYCpvcW8mVw': 'channel',
#  'UCsX8MJHEI5UukXoF3HLnTvg': 'channel',
#  'UCtLo4nwb3ObCDZ4m8b8u7fA': 'channel',
#  'UCtVnAr55ALHAuI7Yyz4GZWg': 'channel',
#  'UCv7k2MRsY9sXIAWpCOvLCjg': 'channel',
#  'UCwCcE-TAVIsYWnZ4oUjU6ew': 'channel',
#  'UCxNjRQKDk_-bVWC0VQFIJzQ': 'channel',
#  'UCxc0F7BSsl3d4V2aoietV9A': 'channel',
#  'UCy3Sj6KflkLCaaLtj2fSnow': 'channel',
#  'a0916xxx258': 'user',
#  'aiudesk': 'user',
#  'avntisdouga': 'user',
#  'bunkei1113': 'user',
#  'ckaikd0021': 'user',
#  'crown6569': 'user',
#  'eguri89': 'user',
#  'fuughaya': 'user',
#  'guccinoheya': 'user',
#  'himawari7859': 'user',
#  'hittyaso': 'user',
#  'jetdaisuke': 'user',
#  'jibanyan': 'user',
#  'jintomikku': 'user',
#  'k2eizo': 'user',
#  'kandorishinobu': 'user',
#  'kashimacitycom': 'user',
#  'katumatahakubutukan': 'user',
#  'kazuch0924': 'user',
#  'kinoyuu0204': 'user',
#  'kirizakieizi': 'user',
#  'kp4940': 'user',
#  'kumamikicraft': 'user',
#  'kyoryugerJP': 'user',
#  'leonanmt': 'user',
#  'mabbits777': 'user',
#  'namihashimotochannel': 'user',
#  'natti0211MH': 'user',
#  'negaheyoukoso': 'user',
#  'nm0525skywalker': 'user',
#  'pockysweets': 'user',
#  'pokonyan1185': 'user',
#  'sasakiasahi': 'user',
#  'satotintv': 'user',
#  'shindatemika': 'user',
#  'shuuya007': 'user',
#  'takuxtuti0502': 'user',
#  'taride008': 'user',
#  'tocorice': 'user',
#  'torokeroTV': 'user',
#  'tryTV92': 'user',
#  'wotakufighter2121': 'user',
#  'yoorai0121': 'user'}

# %%
# connection build
YT = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

# %%
channel_info_dic = {}
for uid, flag in channel_dic.items():
    if flag == 'user': channel_feed = YT.channels().list(part="id,snippet,statistics",forUsername=uid).execute()
    elif flag == 'c': continue # ???
    else: channel_feed = YT.channels().list(part="id,snippet,statistics",id=uid).execute()
    id = channel_feed.get("items",[])[0]['id']
    channel_info_dic[id] = channel_feed.get("items",[])[0]

# %%
# YouTuber
df_cols = get_cols( channel_info_tree )
rows = get_rows_channel( channel_info_dic, channel_info_tree )
df = pd.DataFrame( rows, columns=df_cols )
# id ... d.replace('-','__') # id '-'を'__'に置換

df.to_csv( 'output/UUUM.csv' )

# %%
save_dir = 'output/channel_csv_0702'
roop = 0
for uid, flag in channel_dic.items():
    roop += 1
    print( roop, uid, flag )
    if flag == 'user':
        channel_feed = YT.channels().list(part="id",forUsername=uid).execute()
        CHANNEL_ID = channel_feed.get("items",[])[0]['id']
    elif flag == 'c':
        print( 'skip...' )
        continue # ???
    else:
        CHANNEL_ID = uid
    if os.path.exists( '%s/%s.csv' % ( save_dir, CHANNEL_ID ) ):
        continue
    print("\t get_video_idx ...")
    channel_videos = get_channel_vlist_quick( YT, CHANNEL_ID, 500 )
    print("\t get_video_details ...");
    vlist_details = [ get_video_detail( i ) for i in channel_videos ]    
    channel_video_info = {}
    for i, v_detail in enumerate(vlist_details): channel_video_info[i] = v_detail
    df_cols = get_cols( info_tree )
    rows = get_rows( channel_video_info, info_tree )
    df = pd.DataFrame( rows, columns=df_cols )
    df.to_csv( '%s/%s.csv' % ( save_dir, CHANNEL_ID ) )
# Out:
# 1 HikakinTV user
# 2 0214mex user
# 3 SeikinTV user
# 4 eguri89 user
# 5 PDSKabushikiGaisha user
# 6 MasuoTV user
# 7 kinoyuu0204 user
# 8 kazuch0924 user
# 9 jintomikku user
# 10 jetdaisuke user
# 11 MEGUMIbernadette user
# 12 avntisdouga user
# 13 MASAIandHamzael user
# 14 UCpOjLndjOqMoffA-fr8cbKA channel
# 15 UCosy7jwSdXUbLbJBYgyRcnw channel
# 16 torokeroTV user
# 17 UCCJel9mmTsxDU9RiCwdiLiA channel
# 18 hittyaso user
# 19 kandorishinobu user
# 20 yoorai0121 user
# 21 satotintv user
# 22 nm0525skywalker user
# 23 TAKASHIsTV user
# 24 himawari7859 user
# 25 UC1MwWJ2mFWp51xy9yzyhTlg channel
# 26 UCM5R7AjTi7irA9fXorxRTRg channel
# 27 ASFFFFD1 user
# 28 kirizakieizi user
# 29 UCoG2iDwh5Vw61kZx0kWL0WA channel
# 30 UCMsuwHzQPFMDtHaoR7_HDxg channel
# 31 kashimacitycom user
# 32 UCqQ6BtItfK2FI3f4wubJmoA channel
# 33 UC0JR9ZTJIvB9VX8xz7LyujA channel
# 34 tryTV92 user
# 35 IORIKUNTV user
# 36 UCR1_4Tla5MlZlDK8WM5vklA channel
# 37 UCCO_itOx-wopeBohj5oPkzg channel
# 38 bunkei1113 user
# 39 UCh1K2JtxIZLnUaTPlxPPzjw channel
# 40 UCPzqjzrvmSA9dVydRdAX6Xg channel
# 41 UC9nM3v1ZWwALi0vsVuS_v5g channel
# 42 UCdtFmWwPlKiCOEND_95fwiA channel
# 43 TokaiOnAir user
# 44 UClX3YSREJp3ELuv2wFAYOzA channel
# 45 UC-C5UUZqky2qJmG4EzRnI0g channel
# 46 UCg9mwxF0uacG3Q4N91wo2TQ channel
# 47 UCftut9Z6S48igRNSQRDpCCg channel
# 48 UCPyNsNSTUtywkekbDdCA_8Q channel
# 49 UCIQzfXsmjUObTWvg93gySgw channel
# 50 UCsX8MJHEI5UukXoF3HLnTvg channel
# 51 UC3LAEwEhZ0Yn3l4-WatZo2Q channel
# 52 UCFKSFhVMtIu7akVuxPtXtQw channel
# 53 KanonRintarou c
# skip...
# 54 UC2RdeFmVA1PrDqmFqJMG7hA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 55 UCD3Bl7pISGIQBDMGGP2qLQw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 56 ShihoRimi user
# 	 get_video_idx ...
# 	 get_video_details ...
# 57 SRGAME1000 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 58 UC4bSJdI2RTNSld1_M_liO0w channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 59 pockysweets user
# 	 get_video_idx ...
# 	 get_video_details ...
# 60 UCrUfBW0jCq2HNYCpvcW8mVw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 61 guccinoheya user
# 	 get_video_idx ...
# 	 get_video_details ...
# 62 tocorice user
# 	 get_video_idx ...
# 	 get_video_details ...
# 63 jibanyan user
# 	 get_video_idx ...
# 	 get_video_details ...
# 64 pokonyan1185 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 65 natti0211MH user
# 	 get_video_idx ...
# 	 get_video_details ...
# 66 UCiotlpambU2VW-eM-B2MTcg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 67 UC0cpUGlqr4YlEmRG7543dEg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 68 TUTTITV1 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 69 UCv7k2MRsY9sXIAWpCOvLCjg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 70 kp4940 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 71 takuxtuti0502 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 72 UCE3JA4z-hyR3VRrsRSt3udA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 73 negaheyoukoso user
# 	 get_video_idx ...
# 	 get_video_details ...
# 74 UCEnkd5D-53MDGpgpiQRbUqw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 75 UCg_Wchs_AGoHrlayD_rhO0Q channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 76 crown6569 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 77 UCxNjRQKDk_-bVWC0VQFIJzQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 78 fuughaya user
# 	 get_video_idx ...
# 	 get_video_details ...
# 79 UCmE4PWzOmGXz4eoYD_6jZ0g channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 80 UCh7bThzNArch6TgoHB1HVhA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 81 UC5l9qmpr3ym8BpyKCHio5kQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 82 UCgpmBtbVmsfwqhU_pU5CA3g channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 83 UCSrnV0SB1W2mYW4YMc9VTmg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 84 UCSdiXqnTXy6hukTURUIZbIg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 85 UCZ5yaAP0B-tBKl63ABFmqVQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 86 UC-8H678xX1SNBOM10_ReY6Q channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 87 shuuya007 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 88 UCM3yhFc0-fBFuvqx1Vg2YNQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 89 UC0_nOHqfcBd8Jzx9YGXJ6AQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 90 UCiJvvLq45i4sC4-dTiV88SQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 91 UCXqocGp-RQ_sTw8EpPDg10A channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 92 Maguro29Jp c
# skip...
# 93 UCmol_xpWkIbQU0ZCuinqpQA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 94 sasakiasahi user
# 	 get_video_idx ...
# 	 get_video_details ...
# 95 kumamikicraft user
# 	 get_video_idx ...
# 	 get_video_details ...
# 96 SekineRisa user
# 	 get_video_idx ...
# 	 get_video_details ...
# 97 UCgpq8b6bCzkSLquNQeSE6QQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 98 namihashimotochannel user
# 	 get_video_idx ...
# 	 get_video_details ...
# 99 AmiBeautyTV user
# 	 get_video_idx ...
# 	 get_video_details ...
# 100 MizukittyV user
# 	 get_video_idx ...
# 	 get_video_details ...
# 101 shindatemika user
# 	 get_video_idx ...
# 	 get_video_details ...
# 102 TheMorusaism user
# 	 get_video_idx ...
# 	 get_video_details ...
# 103 UCL-a2oIp9rekDc3Z79uTUPg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 104 UCmsA3A5_HKBwI9OktSttTFg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 105 UCtVnAr55ALHAuI7Yyz4GZWg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 106 UCNS93jTKjnzNG7pYUCN5PrQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 107 UC69xoWl5-Y3m-oRFTORIbKw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 108 UCOZ7Kq5_VWBC-TtteAcsRBg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 109 UC5cDspT0XR1E3GpwVyOnwAA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 110 mabbits777 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 111 UCM_Ll26nXOkscq0YSpBmgyg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 112 UCPJOCEIyI3gxXbTqKSsViqg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 113 UC4-TMrb7Mm4KnYx1VsUgcJA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 114 UCLO1yCo0gDgpXhyM0fXfXXA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 115 ABTVnetwork user
# 	 get_video_idx ...
# 	 get_video_details ...
# 116 HiROKiMovies user
# 	 get_video_idx ...
# 	 get_video_details ...
# 117 UCbZFgAVRN3PDZV0O6Ma-c6Q channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 118 taride008 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 119 LEON1CHANNEL1 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 120 k2eizo user
# 	 get_video_idx ...
# 	 get_video_details ...
# 121 UCtLo4nwb3ObCDZ4m8b8u7fA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 122 wotakufighter2121 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 123 UCxc0F7BSsl3d4V2aoietV9A channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 124 katumatahakubutukan user
# 	 get_video_idx ...
# 	 get_video_details ...
# 125 UCNaGf1tJsooAo6W_lrI06zw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 126 kyoryugerJP user
# 	 get_video_idx ...
# 	 get_video_details ...
# 127 UC5AV3B5lr9j7TF96AESgoVQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 128 leonanmt user
# 	 get_video_idx ...
# 	 get_video_details ...
# 129 UCy3Sj6KflkLCaaLtj2fSnow channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 130 UCwCcE-TAVIsYWnZ4oUjU6ew channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 131 aiudesk user
# 	 get_video_idx ...
# 	 get_video_details ...
# 132 ckaikd0021 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 133 70cleam user
# 	 get_video_idx ...
# 	 get_video_details ...
# 134 UCjX7kJYLEAdsaCDnTsWK3Wg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 135 UC7lG26U81JGl0EyMNOmRsjw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 136 UCps4dAbzd30T--mvrCpltgw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 137 UCD-ygDdEbVWgjIH6V1UQlbQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 138 UCCBq7s8VOCyek275uvq5lYQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 139 UCV_S2S-Zs8LeuJxK-T3RQQg channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 140 Blackbear1207 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 141 UCAsviiS5DE0pcuvxPRrrAzQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 142 UCUy-lBPiJYWXTvfYHiCb_-A channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 143 UC99AIUi4psZ98Khq_qU5Hpw channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 144 UC3-I23qIQk-2rwi7cnntIJA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 145 FroggyChiu user
# 	 get_video_idx ...
# 	 get_video_details ...
# 146 UCj_z-Zeqk8LfwVxx0MUdL-Q channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 147 UCHAL5c5PrCSA4ExAlY_gLuQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 148 UCJES7pjHlSyxjEOdb1PNTrA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 149 UCdb7Jw5rprurSCutjT9BW5A channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 150 UC9YOQFPfEUXbulKDtxeqqBA channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 151 UCLh9M5KxWSlIqh2EC8ja_ug channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 152 a0916xxx258 user
# 	 get_video_idx ...
# 	 get_video_details ...
# 153 UCa7KELKe1u9mQ5jWMdIB-HQ channel
# 	 get_video_idx ...
# 	 get_video_details ...
# 154 UCHV8lZJsXdW8lOFr2z8WPcg channel
# 	 get_video_idx ...
# 	 get_video_details ...
